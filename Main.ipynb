# %%
# pandas for data manipulation
import pandas as pd
# sqlalchemy for running sql queries

import sqlalchemy as db

con = db.create_engine('mysql+mysqldb://sammy:12345678@172.17.0.2')
# run sql file
cur = con.connect()

# %%
with open('database.sql') as f:
    cur.execute(db.text(f.read()))

# %%
Products.default_schema_name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 Products.default_schema_name
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'default_schema_name'

# %%
# import from csv
Products = pd.read_csv('Products.csv')
Products.set_index('ProductID', inplace=True)
Products.to_sql('Product', con=con, if_exists = 'append' ,index=True,schema='OnlineStore')
Customers = pd.read_csv('Customer.csv')
Customers.set_index('CustomerID', inplace=True)
Customers.to_sql('Customer', con=con,if_exists ='append', index=True, schema='OnlineStore')
Orders = pd.read_csv('Orders.csv')
Orders.set_index('OrderID', inplace=True)
Orders.to_sql('Orders', con=con, if_exists='append', index=True, schema='OnlineStore')
# Out:
# 10
# Bad pipe message: %s [b'T\x0f\x0e*I\xa4\x12<\x13\x12!z\xb4\x92v\xcfWm \x1bcV">\x1dH\xfcX{\xa5$\xfe\x95\x7f\x88\x1b\xd1\xee\x07\x0f\xd5\x08\xec\x87w\x1aD`\xf0\x18f\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x00+\x00\x03\x02\x03\x04\x00-\x00\x02\x01']
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b'=\x96:\xbd\x0b8\x0b']
# ...
